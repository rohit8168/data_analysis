# %%
import pandas as pd
import statistics as st
from sklearn.impute import SimpleImputer as si
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\preeti\Downloads\googleplaystore.csv")
df['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %% [markdown]
# # handling missing values

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
imputer=si(missing_values=np.nan,strategy='mean')
imputer.fit(df.iloc[ : ,2:3].values)
df.iloc[:,2:3]=imputer.transform(df.iloc[:,2:3].values)
df=df.dropna()
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
print("average rating of apps is :",df['Rating'].mean())
print("min rating is :",df['Rating'].min())
print("max rating is:",max(df['Rating']))
print("standard deviation is :",st.pstdev(df['Rating']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print("average rating of apps is :",df['Rating'].mean())
#       2 print("min rating is :",df['Rating'].min())
#       3 print("max rating is:",max(df['Rating']))
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
for i in df.iloc[:,0:]:
    print("---"*32)
    c=0
    for j in df[i].unique():
        c=c+1
    print('no of unique values in ',i,'is',c)
# Out:
# ------------------------------------------------------------------------------------------------
# no of unique values in  App is 9648
# ------------------------------------------------------------------------------------------------
# no of unique values in  Category is 33
# ------------------------------------------------------------------------------------------------
# no of unique values in  Rating is 40
# ------------------------------------------------------------------------------------------------
# no of unique values in  Reviews is 5999
# ------------------------------------------------------------------------------------------------
# no of unique values in  Size is 457
# ------------------------------------------------------------------------------------------------
# no of unique values in  Installs is 20
# ------------------------------------------------------------------------------------------------
# no of unique values in  Type is 2
# ...

# %%
c=0
df=df.values
for i in df:
    if i[1]=='ART_AND_DESIGN' and i[6]=='Free':
        c=c+1
print(c)
# Out:
# 62

# %% [markdown]
# # no of app in art and desgin category

# %%
df_pr=df[df['Category']=='ART_AND_DESIGN']
df_pr=df_pr[df['Type']=='Free']
print("there are %d apps are free in art and desgin"%(len(df_pr)))
# Out:
# there are 62 apps are free in art and desgin
# C:\Users\preeti\AppData\Local\Temp\ipykernel_13620\3245775365.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_pr=df_pr[df['Type']=='Free']

# %% [markdown]
# #now of app in category art and desgin wih rating more than 4.5

# %%
df_pr=df[df['Category']=='ART_AND_DESIGN']
df_pr=df_pr[df_pr['Rating']>=4.5]
print(len(df_pr))
# Out:
# 26

# %% [markdown]
# # no of family apps with rating 4.5 ang free

# %%
data=df[df['Category']=='FAMILY']
data=data[data['Type']=='Free']
data=data[data['Rating']>=4.5]
print(len(data))
print("__"*32)
data.App
# Out:
# 477
# ________________________________________________________________
# 2014                                          YouTube Kids
# 2016                                                ROBLOX
# 2019                                               Mahjong
# 2020     Super ABC! Learning games for kids! Preschool ...
# 2021                                         Toy Pop Cubes
#                                ...
# 10801                                  Fr Ignacio Outreach
# 10809                Castle Clash: RPG War and Strategy FR
# 10820                                      Fr. Daoud Lamei
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# Name: App, Length: 477, dtype: object

# %%
data.sort_values(by='Rating',ascending=True)
# Out:
#                                                  App Category  Rating  \
# 2014                                    YouTube Kids   FAMILY     4.5
# 4870                            Angry Birds Epic RPG   FAMILY     4.5
# 4966                         Ad-free Triangle Solver   FAMILY     4.5
# 8613                  Guardian Hunter: SuperBrawlRPG   FAMILY     4.5
# 8611   Downtown Mafia: Gang Wars (Mobster Game) Free   FAMILY     4.5
# ...                                              ...      ...     ...
# 7799                             Cr Aviation Academy   FAMILY     5.0
# 7696                                    Foothills CP   FAMILY     5.0
# 5506                                   AQ Ria Retail   FAMILY     5.0
# 8572              DM Buddy » Learn Digital Marketing   FAMILY     5.0
# 10837               Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#        Reviews                Size     Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# # category having max mean rating

# %%
data['Category'].unique()
# Out:
# array(['FAMILY'], dtype=object)

# %%
df.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...
