# %%
import json
import pandas as pd
import numpy as np

# %%
lst=[1,2,3,4,5]
a=pd.Series(lst)
b=pd.Series(data=['rohit','mohit'],index=[1,2])
pd.Series(lst).repeat(6)
pd.Series([1,2]).repeat([10,2]).reset_index(drop=True)
s=a.agg([min,max,sum])
print(s)
a.astype('float')
print(a[a.between(1,4)])
# Out:
# min     1
# max     5
# sum    15
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
with open(r"C:\Users\OM\OneDrive\Desktop\inventory\data.json",'r') as file:
    txt=file.read()
file.close()
data=json.loads(txt)
df=pd.DataFrame(data)
df=df.T
df
print(df.loc[::2,'name'])
print("--"*30)
print(df.iloc[[0,2,3,4],[0,2]])
print("--"*30)
df['price'].astype('int')
df.dtypes
del df['category']

df.describe()
# Out:
# 1001            lichi
# 1003    pain reliever
# 1005       toothbrush
# 1007          mascara
# 1009            blush
# 1011             berr
# Name: name, dtype: object
# ------------------------------------------------------------
#                name           category
# 1001          lichi            grocery
# 1003  pain reliever             health
# 1004      dry pasta            grocery
# 1005     toothbrush  beauty & personal
# ------------------------------------------------------------
#          name  price  quantity        date
# count      11     11        11          11
# unique     11     11         9          11
# top     lichi    230        70  10/03/2021
# freq        1      1         2           1

# %%
data = {'one'   : pd.Series([1, 2, 3, 4]),
        'two'   : pd.Series([10, 20, 30, 40]),
        'three' : pd.Series([100, 200, 300, 400]),
        'four'  : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)
df.drop(['one'],axis=1,inplace=True)
df.dtypes
df.describe()
# Out:
#              two       three         four
# count   4.000000    4.000000     4.000000
# mean   25.000000  250.000000  2500.000000
# std    12.909944  129.099445  1290.994449
# min    10.000000  100.000000  1000.000000
# 25%    17.500000  175.000000  1750.000000
# 50%    25.000000  250.000000  2500.000000
# 75%    32.500000  325.000000  3250.000000
# max    40.000000  400.000000  4000.000000

# %%
def _add_(i,j):
    return i+j
def seq(i):
    return i**2
def r(i):
    return i**0.5

df.pipe(_add_,10).pipe(seq).pipe(r)
df.apply(np.mean)
print(df.apply(r,axis=1))
print(df.reindex([1,2,3]))
print(df.reindex(columns=['four','two','one']))
print(df.rename(columns={'two':2,"three":3,"four":4},inplace=True,index={0:"a",1:"b",2:"c"}))
df
# Out:
#         two      three       four
# 0  3.162278  10.000000  31.622777
# 1  4.472136  14.142136  44.721360
# 2  5.477226  17.320508  54.772256
# 3  6.324555  20.000000  63.245553
#    two  three  four
# 1   20    200  2000
# 2   30    300  3000
# 3   40    400  4000
#    four  two  one
# 0  1000   10  NaN
# 1  2000   20  NaN
# 2  3000   30  NaN
# 3  4000   40  NaN
# None
#     2    3     4
# a  10  100  1000
# b  20  200  2000
# c  30  300  3000
# 3  40  400  4000

# %%
cricket = {'Team'   : ['India', 'India', 'Australia', 'Australia', 'SA', 'SA', 'SA', 'SA', 'NZ', 'NZ', 'NZ', 'India'],
           'Rank'   : [2, 3, 1,2, 3,4 ,1 ,1,2 , 4,1,2],
           'Year'   : [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
           'Points' : [876,801,891,815,776,784,834,824,758,691,883,782]}
Df=pd.DataFrame(data=cricket)
Df
# Out:
#          Team  Rank  Year  Points
# 0       India     2  2014     876
# 1       India     3  2015     801
# 2   Australia     1  2014     891
# 3   Australia     2  2015     815
# 4          SA     3  2014     776
# 5          SA     4  2015     784
# 6          SA     1  2016     834
# 7          SA     1  2017     824
# 8          NZ     2  2016     758
# 9          NZ     4  2014     691
# 10         NZ     1  2015     883
# 11      India     2  2017     782

# %%
data=Df.groupby('Team').groups
data
# Out:
# {'Australia': [2, 3], 'India': [0, 1, 11], 'NZ': [8, 9, 10], 'SA': [4, 5, 6, 7]}

# %%
Data=Df.groupby(['Team','Year']).get_group(('Australia',2015))
print(Data)
print('--'*32)
data=Df.groupby('Team').sum()['Points'].sort_values(ascending=False)
print(data)
print('--'*32)
print(pd.DataFrame(data1))
for I in data1:
    print(type(I),I,len(I))
    print('--'*32)
print("--"*32)
print(data1.filter(lambda x: len(x) == 3 ))
# Out:
#         Team  Rank  Year  Points
# 3  Australia     2  2015     815
# ----------------------------------------------------------------
# Team
# SA           3218
# India        2459
# NZ           2332
# Australia    1706
# Name: Points, dtype: int64
# ----------------------------------------------------------------
#            0                                                  1
# 0  Australia          Team  Rank  Year  Points
# 2  Australia ...
# 1      India       Team  Rank  Year  Points
# 0   India     2 ...
# 2         NZ     Team  Rank  Year  Points
# 8    NZ     2  201...
# 3         SA    Team  Rank  Year  Points
# 4   SA     3  2014 ...
# <class 'tuple'> ('Australia',         Team  Rank  Year  Points
# 2  Australia     1  2014     891
# 3  Australia     2  2015     815) 2
# ----------------------------------------------------------------
# <class 'tuple'> ('India',      Team  Rank  Year  Points
# 0   India     2  2014     876
# 1   India     3  2015     801
# ...

# %%
Df=pd.read_csv(r"C:\Users\OM\Downloads\Football.csv")
Df.head()
# Out:
#   Country   League   Club       Player Names  Matches_Played  Substitution
# 0   Spain  La Liga  (BET)    Juanmi Callejon              19             16  \
# 1   Spain  La Liga  (BAR)  Antoine Griezmann              36              0
# 2   Spain  La Liga  (ATL)        Luis Suarez              34              1
# 3   Spain  La Liga  (CAR)       Ruben Castro              32              3
# 4   Spain  La Liga  (VAL)      Kevin Gameiro              21             10
#
#    Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match
# 0  1849     11   6.62              0.34     48        20                 2.47  \
# 1  3129     16  11.86              0.36     88        41                 2.67
# 2  2940     28  23.21              0.75    120        57                 3.88
# 3  2842     13  14.06              0.47    117        42                 3.91
# 4  1745     13  10.65              0.58     50        23                 2.72
#
#    On Target Per Avg Match  Year
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     626 non-null    object
#  3   Player Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
# ...

# %%
Df.dropna(subset=['Club'],inplace=True)
print(Df.isnull().sum())
Df.to_csv('Number.csv')
# Out:
# Country                    0
# League                     0
# Club                       0
# Player Names               0
# Matches_Played             0
# Substitution               0
# Mins                       0
# Goals                      0
# xG                         0
# xG Per Avg Match           0
# Shots                      0
# OnTarget                   0
# Shots Per Avg Match        0
# On Target Per Avg Match    0
# Year                       0
# dtype: int64

# %%
import pandas_profiling as pp
report = pp.ProfileReport(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 import pandas_profiling as pp
#       2 report = pp.ProfileReport(df)
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
Df.describe([.80])
ds=Df['Goals']
Max=ds.max()
d=Df.loc[Df['Goals']==Max,['Country','Goals']]
print(d)
# Out:
#   Country  Goals
# 5   Spain     42

# %%
de=Df.copy()
de['year+100']=de['Year'] + 100
de
# Out:
#           Country      League   Club       Player Names  Matches_Played
# 0           Spain     La Liga  (BET)    Juanmi Callejon              19  \
# 1           Spain     La Liga  (BAR)  Antoine Griezmann              36
# 2           Spain     La Liga  (ATL)        Luis Suarez              34
# 3           Spain     La Liga  (CAR)       Ruben Castro              32
# 4           Spain     La Liga  (VAL)      Kevin Gameiro              21
# ..            ...         ...    ...                ...             ...
# 654   Netherlands  Eredivisie  (RZA)       Haris Vuckic              23
# 655   Netherlands  Eredivisie  (UTR)        Gyrano Kerk              24
# 656   Netherlands  Eredivisie  (AJA)      Quincy Promes              18
# 657   Netherlands  Eredivisie  (PSV)    Denzel Dumfries              25
# 659   Netherlands  Eredivisie  (PSV)         Cody Gakpo              14
#
#      Substitution   Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget
# ...

# %%
print(de['Country'].unique())
print(de['Country'].nunique())
print(de['Country'].value_counts())
print(Df.isnull().sum())
Df['Club']=Df['Club'].fillna("hello")
Df.isnull()
Df[Df['Club']=='hello']
# Out:
# ['Spain' 'Italy' 'Germany' 'England' 'Brazil' 'France' 'USA' 'Portugal '
#  ' Netherlands']
# 9
# Country
# Italy           98
# Germany         98
# Spain           97
# Brazil          81
# England         79
# France          60
# USA             40
#  Netherlands    39
# Portugal        34
# Name: count, dtype: int64
# Country                    0
# League                     0
# Club                       0
# Player Names               0
# Matches_Played             0
# Substitution               0
# Mins                       0
# Goals                      0
# xG                         0
# xG Per Avg Match           0
# Shots                      0
# OnTarget                   0
# Shots Per Avg Match        0
# On Target Per Avg Match    0
# Year                       0
# dtype: int64
#           Country                          League   Club         Player Names
# 10          Spain                         La Liga  hello              Aduriz   \
# ...
