# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\ml\da\heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
sns.distplot(df['Age'],hist=True,rug=True)
# Out:
# C:\Users\preeti\AppData\Local\Temp\ipykernel_10844\1566459760.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True,rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],hist=True,rug=True,bins=20)
# Out:
# C:\Users\preeti\AppData\Local\Temp\ipykernel_10844\184642970.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True,rug=True,bins=20)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
lis=[(df['Sex']=='M').sum(),(df['Sex']=='F').sum()]
print("no of male is:",lis[0],'no of female is :',lis[-1])
plt.pie(lis,labels=['M','F'],autopct='%0.1ff%%')
plt.show()
# Out:
# no of male is: 725 no of female is : 193

# %%
sns.distplot(df['RestingBP'],hist=True,kde=0)
# Out:
# C:\Users\preeti\AppData\Local\Temp\ipykernel_10844\3342746496.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],hist=True,kde=0)
# <Axes: xlabel='RestingBP'>

# %%
sns.distplot(df['RestingBP'],hist=True,kde=1)
# Out:
# C:\Users\preeti\AppData\Local\Temp\ipykernel_10844\2265930603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],hist=True,kde=1)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'],kde=1)##outlier
# Out:
# C:\Users\preeti\AppData\Local\Temp\ipykernel_10844\413599294.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'],kde=1)##outlier
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['FastingBS'],kde=1)
# Out:
# C:\Users\preeti\AppData\Local\Temp\ipykernel_10844\1571459164.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'],kde=1)
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
df.groupby('ChestPainType').size().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
sns.countplot(x='Sex',hue='HeartDisease',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.violinplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(y=df['Sex'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
print(df.head())
data=df.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],axis=1)
data.corr()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x='Age',y='HeartDisease',data=df,kind='reg')

# %%
sns.jointplot(x='',y='Age',data=df,kind='hex')

# %%
sns.jointplot(x='Age',y='MaxHR',data=df,kind='reg')

# %%
sns.pairplot(df)
